# %% [markdown]
# # Week 3 Homework: The Smart Field Surveyor
#
# In this assignment, you will build a tool that a field researcher would use to log environmental data. Your script must validate the location and categorize the risk level based on user input.
#
# ### The Scenario
# You are monitoring water levels in specific Dutch provinces. Your script should only accept data for provinces in your monitoring list. If the province is valid, you will then ask for the water level and determine the safety status.
#
# ---
#
# ### Your Tasks:
# 1. **Define a list** named `active_provinces` containing: `"Utrecht"`, `"Friesland"`, and `"Zeeland"`.
# 2. **Ask the user** for their current province using `input()`.
# 3. **Check** if the entered province is in your `active_provinces` list.
# 4. **If valid:** Ask the user for the current `water_level` (as a float).
#    - If the level is **above 2.0**, print: `"ALARM: Flood risk in [Province]!"`.
#    - If the level is **between 0.5 and 2.0**, print: `"Status: Normal."`.
#    - If the level is **below 0.5**, print: `"Status: Low water level."`.
# 5. **If NOT valid:** Print: `"Error: Province not in monitoring network."`.

# %%
# 1. Create the list
active_provinces = ["Utrecht", "Friesland", "Zeeland"]

# 2. Get user input for province
user_prov = input("Enter province name: ")

# 3. Start your Logic (If/Else)
# Hint: Use 'if user_prov in active_provinces:'

# %% [markdown]
# <details>
#   <summary><b>🔍 Need a hint with the structure?</b></summary>
#
#   Remember that `input()` always returns a **string**. If you want to compare the water level as a number, you must convert it using `float()`.
#
#   ```python
#   if user_prov in active_provinces:
#       level = float(input("Enter water level: "))
#       if level > 2.0:
#           print(f"ALARM: Flood risk in {user_prov}!")
#       # Add your elif and else here...
#   else:
#       print("Error: Province not in monitoring network.")
#   ```
# </details>
