# %% [markdown]
# # Week 3 Huiswerk: De Slimme Veldonderzoeker
#
# In deze opdracht ga je een tool bouwen die een veldonderzoeker kan gebruiken om milieugegevens te loggen. Je script moet de locatie valideren en het risiconiveau categoriseren op basis van gebruikersinvoer.
#
# ### Het Scenario
# Je monitort de waterstanden in specifieke Nederlandse provincies. Je script mag alleen data accepteren voor provincies die in je monitoringlijst staan. Als de provincie geldig is, vraag je vervolgens om de waterstand en bepaal je de veiligheidsstatus.
#
# ---
#
# ### Je Taken:
# 1. **Definieer een lijst** genaamd `active_provinces` met daarin: `"Utrecht"`, `"Friesland"`, en `"Zeeland"`.
# 2. **Vraag de gebruiker** om hun huidige provincie met behulp van `input()`.
# 3. **Controleer** of de ingevoerde provincie in je `active_provinces` lijst staat.
# 4. **Indien geldig:** Vraag de gebruiker om de huidige `water_level` (als een float).
#    - Als het niveau **boven 2.0** is, print: `"ALARM: Flood risk in [Province]!"`.
#    - Als het niveau **tussen 0.5 en 2.0** ligt, print: `"Status: Normal."`.
#    - Als het niveau **onder 0.5** is, print: `"Status: Low water level."`.
# 5. **Indien NIET geldig:** Print: `"Error: Province not in monitoring network."`.

# %%
# 1. Create the list
active_provinces = ["Utrecht", "Friesland", "Zeeland"]

# 2. Get user input for province
user_prov = input("Enter province name: ")

# 3. Start your Logic (If/Else)
# Hint: Use 'if user_prov in active_provinces:'

# %% [markdown]
# <details>
#   <summary><b>🔍 Hulp nodig met de structuur?</b></summary>
#
#   Onthoud dat `input()` altijd een **string** teruggeeft. Als je de waterstand wilt vergelijken als een getal, moet je deze omzetten met `float()`.
#
#   ```python
#   if user_prov in active_provinces:
#       level = float(input("Enter water level: "))
#       if level > 2.0:
#           print(f"ALARM: Flood risk in {user_prov}!")
#       # Add your elif and else here...
#   else:
#       print("Error: Province not in monitoring network.")
#   ```
# </details>
