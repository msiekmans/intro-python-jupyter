# %% [markdown]
# # Week 1, Part 2: Working with Variables
#
# In the last exercise, we used Python as a calculator. Now, we will learn how to **store** those results so we can use them later.
#
# **Key Concept:** In Python, the `=` sign is the **assignment operator**. It takes the value on the right and stores it under the name on the left.
#
# ```python
# name_of_variable = 100
# ```

# %% [markdown]
# ---
# ## Assignment 1: Naming a Location
# **Goal:** Create a **String** (text) variable.
#
# **Task:** Create a variable called `city_name` and assign it the name of a city (e.g., "Amsterdam" or "Tokyo"). Remember to use quotation marks for text! Then print it.

# %% [markdown]
# ---
# ## Assignment 2: Coordinate Storage
# **Goal:** Store **Floats** (decimal numbers).
#
# **Task:** Create two variables: `lat` and `lon`. Assign them the values `48.85` and `2.29` (the coordinates for the Eiffel Tower). Print it also.

# %% [markdown]
# ---
# ## Assignment 3: Variable Reuse
# **Goal:** Use one variable to define another.
#
# **Task:**
# 1. Create a variable `radius` and set it to `10`.
# 2. Create a variable `diameter` and set it to `radius * 2`.
# 3. Print the `diameter`.

# %% [markdown]
# ---
# ## Assignment 4: The F-String
# **Goal:** Inject variables into a sentence.
#
# **Task:** Create a variable `country = "Netherlands"`. Use an **f-string** (starting with `f"..."`) to print the sentence: `I am mapping the country of Netherlands.`
#
# For example:
# ```python
# first_name = "John"
# last_name = "Doe"
# print(f"Welcome, {first_name} {last_name}!")
#
# ```

# %% [markdown]
# ---
# ## Assignment 5: Dynamic Updates
# **Goal:** Change the value of an existing variable.
#
# **Task:**
# 1. Create a variable `sensor_count = 5`.
# 2. On the next line, update it: `sensor_count = sensor_count + 1`.
# 3. Print the result. (It should be 6).

# %% [markdown]
# ---
# ## Assignment 6: Booleans
# **Goal:** Store True/False values.
#
# **Task:** Create a variable `is_water` and set it to `True`. Create another called `is_land` and set it to `False`. (Note: True and False must be capitalized in Python!)
# Print the results.

# %% [markdown]
# ---
# ## Assignment 7: Conversion Calculations
# **Goal:** Multiple steps with variables.
#
# **Task:**
# 1. Create `width = 500` and `length = 1000` (in meters).
# 2. Create `area_m2` by multiplying them.
# 3. Create `area_km2` by dividing `area_m2` by `1000000`.
# 4. Print the final `area_km2`.

# %% [markdown]
# ---
# ## Assignment 8: Constants
# **Goal:** Practice naming conventions.
#
# **Task:** In programming, we use ALL_CAPS for values that don't change.
# Create a variable `EARTH_RADIUS_KM = 6371`.
# Create a vairable `PI = 3.14159`.
# Calculate the earth's circumference ($2 * PI * RADIUS$) using these variables.

# %% [markdown]
# ---
# ## Assignment 9: String Addition
# **Goal:** Combining text.
#
# **Task:** Create `part1 = "Geo"` and `part2 = "spatial"`. Add them together using the `+` sign and store the result in a variable called `field_of_study`. Print it.

# %% [markdown]
# ---
# ## Assignment 10: The Surveyor's Challenge (Heron's Formula)
# **Goal:** Use descriptive variable names to solve a complex formula.
#
# **Task:** Find the area of a triangle with sides **a=50**, **b=120**, and **c=130**.
#
# 1. Assign `a`, `b`, and `c` their values.
# 2. Calculate the semi-perimeter `s = (a + b + c) / 2`.
# 3. Calculate `final_area = (s * (s - a) * (s - b) * (s - c)) ** 0.5`.
# 4. Print `final_area`.
