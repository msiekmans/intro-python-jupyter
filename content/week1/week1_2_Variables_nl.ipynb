# %% [markdown]
# # Week 1, Deel 2: Werken met variabelen
#
# In de vorige oefening hebben we Python gebruikt als rekenmachine. Nu gaan we leren hoe we die resultaten kunnen **opslaan** om ze later te gebruiken.
#
# **Kernbegrip:** In Python is het `=` teken de **toewijzingsoperator** (assignment operator). Het neemt de waarde aan de rechterkant en slaat deze op onder de naam aan de linkerkant.
#
# ```python
# naam_van_variabele = 100
# ```

# %% [markdown]
# ---
# ## Opdracht 1: Een locatie een naam geven
# **Doel:** Maak een **String** (tekst) variabele aan.
#
# **Taak:** Maak een variabele genaamd `city_name` en wijs hier de naam van een stad aan toe (bijv. "Amsterdam" of "Tokyo"). Vergeet niet om aanhalingstekens te gebruiken voor tekst! Print de variabele vervolgens.

# %% [markdown]
# ---
# ## Opdracht 2: Coördinaten opslaan
# **Doel:** Sla **Floats** (decimale getallen) op.
#
# **Taak:** Maak twee variabelen aan: `lat` en `lon`. Wijs hier de waarden `48.85` en `2.29` aan toe (de coördinaten van de Eiffeltoren). Print ze ook.

# %% [markdown]
# ---
# ## Opdracht 3: Variabelen hergebruiken
# **Doel:** Gebruik de ene variabele om de andere te definiëren.
#
# **Taak:**
# 1. Maak een variabele `radius` aan en stel deze in op `10`.
# 2. Maak een variabele `diameter` aan en stel deze in op `radius * 2`.
# 3. Print de `diameter`.

# %% [markdown]
# ---
# ## Opdracht 4: De F-String
# **Doel:** Variabelen invoegen in een zin.
#
# **Taak:** Maak een variabele `country = "Netherlands"`. Gebruik een **f-string** (beginnend met `f"..."`) om de volgende zin te printen: `I am mapping the country of Netherlands.`
#
# Bijvoorbeeld:
# ```python
# first_name = "John"
# last_name = "Doe"
# print(f"Welcome, {first_name} {last_name}!")
#
# ```

# %% [markdown]
# ---
# ## Opdracht 5: Dynamische updates
# **Doel:** De waarde van een bestaande variabele wijzigen.
#
# **Taak:**
# 1. Maak een variabele `sensor_count = 5`.
# 2. Werk deze op de volgende regel bij: `sensor_count = sensor_count + 1`.
# 3. Print het resultaat. (Dit moet 6 zijn).

# %% [markdown]
# ---
# ## Opdracht 6: Booleans
# **Doel:** True/False-waarden opslaan.
#
# **Taak:** Maak een variabele `is_water` aan en stel deze in op `True`. Maak een andere genaamd `is_land` aan en stel deze in op `False`. (Let op: True en False moeten met een hoofdletter geschreven worden in Python!)
# Print de resultaten.

# %% [markdown]
# ---
# ## Opdracht 7: Omrekenberekeningen
# **Doel:** Meerdere stappen met variabelen.
#
# **Taak:**
# 1. Maak `width = 500` en `length = 1000` (in meters).
# 2. Maak `area_m2` aan door ze met elkaar te vermenigvuldigen.
# 3. Maak `area_km2` aan door `area_m2` te delen door `1000000`.
# 4. Print de uiteindelijke `area_km2`.

# %% [markdown]
# ---
# ## Opdracht 8: Constanten
# **Doel:** Oefenen met naamgevingsconventies.
#
# **Taak:** In programmeren gebruiken we HOOFDLETTERS voor waarden die niet veranderen.
# Maak een variabele `EARTH_RADIUS_KM = 6371`.
# Maak een variabele `PI = 3.14159`.
# Bereken de omtrek van de aarde ($2 * PI * RADIUS$) met behulp van deze variabelen.

# %% [markdown]
# ---
# ## Opdracht 9: Tekst samenvoegen (String Addition)
# **Doel:** Tekst combineren.
#
# **Taak:** Maak `part1 = "Geo"` en `part2 = "spatial"`. Voeg ze samen met het `+` teken en sla het resultaat op in een variabele genaamd `field_of_study`. Print deze.

# %% [markdown]
# ---
# ## Opdracht 10: De Landmetersuitdaging (Formule van Heron)
# **Doel:** Duidelijke variabelenamen gebruiken om een complexe formule op te lossen.
#
# **Taak:** Vind de oppervlakte van een driehoek met zijden **a=50**, **b=120**, en **c=130**.
#
# 1. Wijs aan `a`, `b`, en `c` hun waarden toe.
# 2. Bereken de halve omtrek `s = (a + b + c) / 2`.
# 3. Bereken `final_area = (s * (s - a) * (s - b) * (s - c)) ** 0.5`.
# 4. Print `final_area`.
