# %% [markdown]
# # Week 2.2: Meer kracht met Loops
# In Geomaps en Data verwerken we vaak duizenden coördinaten of sensormetingen. Door loops te gebruiken kunnen we al die data binnen milliseconden verwerken.
#
# ---
# ## Deel 1: Itereren en Transformeren
# Het transformeren van data betekent het veranderen van elk item in een lijst (bijvoorbeeld het omrekenen van eenheden).

# %% [markdown]
# ### Opdracht 1: Temperatuur Omrekenen
# Je hebt een lijst met bodemtemperaturen in Celsius: `temps_c = [12, 15, 21, 18]`.
# Doorloop de lijst met een loop en print elke temperatuur omgerekend naar **Fahrenheit**.
#
# *Formule: (C * 1.8) + 32*

# %%
temps_c = [12, 15, 21, 18]
# Your code here

# %% [markdown]
# <details>
#   <summary><b>💡 Tip & Oplossing</b></summary>
#
#   ```python
#   for c in temps_c:
#       f = (c * 1.8) + 32
#       print(f"{c}°C is {f}°F")
#   ```
# </details>

# %% [markdown]
# ### Opdracht 2: Coördinaten Schalen
# Door een kaartfout zijn je data verschoven. Je hebt een lijst met X-coördinaten: `x_coords = [100, 200, 300]`.
# Doorloop ze met een loop en print elke coördinaat vermenigvuldigd met **1.05**.

# %%
x_coords = [100, 200, 300]
# Your code here

# %% [markdown]
# ### Opdracht 3: Labelmaker
# Maak een lijst van 3 fruitsoorten die in een boomgaard te vinden zijn: `["Apple", "Pear", "Cherry"]`.
# Doorloop ze met een loop en print een label voor elke soort: `"Orchard Type: [Name]"`.

# %%
# Your code here

# %% [markdown]
# ---
# ## Deel 2: Data Filteren
# Filteren betekent dat je alleen actie onderneemt op items die aan een bepaalde voorwaarde voldoen.

# %% [markdown]
# ### Opdracht 4: Het Hoogtefilter
# Een drone vliegt op deze hoogtes: `heights = [50, 130, 80, 160, 40]`.
# Doorloop de lijst en print **alleen** de hoogtes die **boven de 120 meter** liggen.

# %%
heights = [50, 130, 80, 160, 40]
# Your code here

# %% [markdown]
# <details>
#   <summary><b>💡 Tip & Oplossing</b></summary>
#
#   ```python
#   for h in heights:
#       if h > 120:
#           print(f"Warning: {h}m is too high!")
#   ```
# </details>

# %% [markdown]
# ### Opdracht 5: Zeeniveau-controle
# Je hebt dieptes: `depths = [-10, -5, 2, -8, 1]`.
# Doorloop ze met een loop en print `"Below Sea Level"` als het getal negatief is, en `"Above Sea Level"` als het positief is.

# %%
depths = [-10, -5, 2, -8, 1]
# Your code here

# %% [markdown]
# ### Opdracht 6: Amsterdam Zoeken
# Doorloop de lijst `cities = ["Rotterdam", "Utrecht", "Amsterdam", "Leiden"]`.
# Als de stad `"Amsterdam"` is, print dan `"Destination Reached!"`. Voor alle andere steden print je `"Passing [City]..."`.

# %%
cities = ["Rotterdam", "Utrecht", "Amsterdam", "Leiden"]
# Your code here

# %% [markdown]
# ---
# ## Deel 3: Tellen en Optellen
# Een loop gebruiken om één enkel resultaat te berekenen uit een hele lijst.

# %% [markdown]
# ### Opdracht 7: Sensoren Tellen
# Je hebt een lijst: `data = ["Valid", "Error", "Valid", "Valid", "Error"]`.
# Maak een variabele `error_count = 0` aan. Doorloop de lijst met een loop, en voeg voor elke `"Error"` 1 toe aan de telling. Print de uiteindelijke telling.

# %%
data = ["Valid", "Error", "Valid", "Valid", "Error"]
error_count = 0
# Your code here

# %% [markdown]
# <details>
#   <summary><b>💡 Tip & Oplossing</b></summary>
#
#   ```python
#   for status in data:
#       if status == "Error":
#           error_count = error_count + 1
#   print(f"Total errors found: {error_count}")
#   ```
# </details>

# %% [markdown]
# ### Opdracht 8: Totaal aan Neerslag
# Wekelijkse neerslag in mm: `rain = [5, 0, 12, 3, 0, 0, 8]`.
# Bereken de totale neerslag voor de week met behulp van een loop en een `total` variabele.

# %%
rain = [5, 0, 12, 3, 0, 0, 8]
total = 0
# Your code here

# %% [markdown]
# ---
# ## Deel 4: Werken met Ranges
# De `range()` functie wordt gebruikt om een actie een specifiek aantal keren te herhalen.

# %% [markdown]
# ### Opdracht 9: ID-generator
# Gebruik `range()` om de getallen van **10 tot en met 15** af te drukken. Dit zouden ID's kunnen zijn voor nieuwe kaartmarkers.

# %%
# Your code here

# %% [markdown]
# ### Opdracht 10: Het Aftellen
# Gebruik `range(5, 0, -1)` om een countdown te maken van 5 naar 1. Print na de loop `"Launch Map!"`.

# %%
# Your code here

# %% [markdown]
# <details>
#   <summary><b>💡 Tip & Oplossing</b></summary>
#
#   ```python
#   for i in range(5, 0, -1):
#       print(i)
#   print("Launch Map!")
#   ```
# </details>
