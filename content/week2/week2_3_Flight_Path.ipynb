# %% [markdown]
# # Week 2 Homework: The Drone Flight Analyzer
# In this assignment, you will analyze a flight path consisting of several GPS waypoints. Each waypoint is a list containing `[Latitude, Longitude, Altitude]`.
#
# ### The Data
# Copy this list into your code cell:
# ```python
# flight_path = [
#     [52.3702, 4.8952, 10],  # Takeoff
#     [52.3710, 4.8960, 45],
#     [52.3725, 4.8975, 125], # High altitude
#     [52.3740, 4.8990, 135], # High altitude
#     [52.3755, 4.9005, 30]   # Landing approach
# ]
# ```
#
# ---
# ### Your Tasks:
# 1. **Iterate** through the `flight_path` using a `for` loop.
# 2. **Extract** the altitude (the 3rd value) for each waypoint.
# 3. **Check** if the altitude is above **120 meters** (the legal limit for many drones).
# 4. **Count** how many waypoints were illegal.
# 5. **Print** a summary at the end: `"Total illegal waypoints found: [count]"`.

# %%
flight_path = [
    [52.3702, 4.8952, 10], 
    [52.3710, 4.8960, 45],  
    [52.3725, 4.8975, 125], 
    [52.3740, 4.8990, 135], 
    [52.3755, 4.9005, 30]   
]

illegal_count = 0

# Start your loop here...

# %% [markdown]
# <details>
#   <summary><b>🔍 Stuck? Click for a hint</b></summary>
#
#   To get the altitude from a waypoint inside the loop, use `waypoint[2]`.
#   Inside the loop, use an `if` statement to check if the altitude > 120, and if so, add 1 to your `illegal_count`.
#
#   ```python
#   for pt in flight_path:
#       altitude = pt[2]
#       if altitude > 120:
#           print(f"Violation detected at {altitude}m!")
#           illegal_count += 1
#
#   print(f"Total illegal waypoints found: {illegal_count}")
#   ```
# </details>
