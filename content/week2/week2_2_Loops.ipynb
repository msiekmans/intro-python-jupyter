# %% [markdown]
# # Week 2.2: Powering Up with Loops
# In Geomaps and Data, we often deal with thousands of coordinates or sensor readings. Using loops allows us to process all that data in milliseconds.
#
# ---
# ## Part 1: Iterating and Transforming
# Transforming data means changing every item in a list (e.g., converting units).

# %% [markdown]
# ### Assignment 1: Temperature Conversion
# You have a list of ground temperatures in Celsius: `temps_c = [12, 15, 21, 18]`.
# Loop through the list and print each temperature converted to **Fahrenheit**.
#
# *Formula: (C * 1.8) + 32*

# %%
temps_c = [12, 15, 21, 18]
# Your code here

# %% [markdown]
# <details>
#   <summary><b>🔍 Hint & Solution</b></summary>
#
#   ```python
#   for c in temps_c:
#       f = (c * 1.8) + 32
#       print(f"{c}°C is {f}°F")
#   ```
# </details>

# %% [markdown]
# ### Assignment 2: Scaling Coordinates
# A mapping error shifted your data. You have a list of X-coordinates: `x_coords = [100, 200, 300]`.
# Loop through them and print each coordinate multiplied by **1.05**.

# %%
x_coords = [100, 200, 300]
# Your code here

# %% [markdown]
# ### Assignment 3: Label Maker
# Create a list of 3 fruit types found in an orchard: `["Apple", "Pear", "Cherry"]`.
# Loop through them and print a label for each: `"Orchard Type: [Name]"`.

# %%
# Your code here

# %% [markdown]
# ---
# ## Part 2: Filtering Data
# Filtering means only acting on items that meet a certain condition.

# %% [markdown]
# ### Assignment 4: The Altitude Filter
# A drone is flying at these altitudes: `heights = [50, 130, 80, 160, 40]`.
# Loop through the list and **only** print the altitudes that are **above 120 meters**.

# %%
heights = [50, 130, 80, 160, 40]
# Your code here

# %% [markdown]
# <details>
#   <summary><b>🔍 Hint & Solution</b></summary>
#
#   ```python
#   for h in heights:
#       if h > 120:
#           print(f"Warning: {h}m is too high!")
#   ```
# </details>

# %% [markdown]
# ### Assignment 5: Sea Level Check
# You have depths: `depths = [-10, -5, 2, -8, 1]`.
# Loop through them and print `"Below Sea Level"` if the number is negative, and `"Above Sea Level"` if it is positive.

# %%
depths = [-10, -5, 2, -8, 1]
# Your code here

# %% [markdown]
# ### Assignment 6: Finding Amsterdam
# Loop through the list `cities = ["Rotterdam", "Utrecht", "Amsterdam", "Leiden"]`.
# If the city is `"Amsterdam"`, print `"Destination Reached!"`. For all other cities, print `"Passing [City]..."`.

# %%
cities = ["Rotterdam", "Utrecht", "Amsterdam", "Leiden"]
# Your code here

# %% [markdown]
# ---
# ## Part 3: Counting and Accumulating
# Using a loop to calculate a single result from a whole list.

# %% [markdown]
# ### Assignment 7: Count the Sensors
# You have a list: `data = ["Valid", "Error", "Valid", "Valid", "Error"]`.
# Create a variable `error_count = 0`. Loop through the list, and for every `"Error"`, add 1 to the count. Print the final count.

# %%
data = ["Valid", "Error", "Valid", "Valid", "Error"]
error_count = 0
# Your code here

# %% [markdown]
# <details>
#   <summary><b>🔍 Hint & Solution</b></summary>
#
#   ```python
#   for status in data:
#       if status == "Error":
#           error_count = error_count + 1
#   print(f"Total errors found: {error_count}")
#   ```
# </details>

# %% [markdown]
# ### Assignment 8: Sum of Rainfall
# Weekly rainfall in mm: `rain = [5, 0, 12, 3, 0, 0, 8]`.
# Calculate the total rainfall for the week using a loop and a `total` variable.

# %%
rain = [5, 0, 12, 3, 0, 0, 8]
total = 0
# Your code here

# %% [markdown]
# ---
# ## Part 4: Working with Ranges
# The `range()` function is used to repeat an action a specific number of times.

# %% [markdown]
# ### Assignment 9: ID Generator
# Use `range()` to print the numbers from **10 to 15**. These could be IDs for new map markers.

# %%
# Your code here

# %% [markdown]
# ### Assignment 10: The Countdown
# Use `range(5, 0, -1)` to create a countdown from 5 to 1. After the loop, print `"Launch Map!"`.

# %%
# Your code here

# %% [markdown]
# <details>
#   <summary><b>🔍 Hint & Solution</b></summary>
#
#   ```python
#   for i in range(5, 0, -1):
#       print(i)
#   print("Launch Map!")
#   ```
# </details>
